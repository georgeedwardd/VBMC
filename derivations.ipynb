# %% [markdown]
# # Derivations
# ---

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### 1.A

# %% [markdown]
# #### Integrating a Function $f(t)$
#
# Let
#
# $$
# f \sim \mathcal{GP}(m(x), k(x,x')),
# $$
#
# where $m(x)$ is the mean function and $k(x,x')$ is the covariance kernel of the Gaussian Process.
#
# Consider the integral process
#
# $$
# F(x)=\int_a^x f(t)\,dt.
# $$
#
# Since integration is a **linear operator**, the integral of a Gaussian Process remains Gaussian. Consequently, $F(x)$ is itself a Gaussian Process whose mean and covariance can be derived analytically.
#
# ---
#
# **Prior Mean Function**
#
# The prior mean of the integrated process is
#
# $$
# \begin{aligned}
# M(x)
# &=\mathbb{E}[F(x)]\\
# &=\mathbb{E}\left[\int_a^x f(t)\,dt\right]\\
# &=\int_a^x \mathbb{E}[f(t)]\,dt\\
# &=\int_a^x m(t)\,dt.
# \end{aligned}
# $$
#
# ---
#
# **Prior Covariance Function**
#
# The covariance structure follows from the covariance of the underlying GP:
#
# $$
# \begin{aligned}
# K(x,x')
# &=\operatorname{Cov}\Big(F(x),F(x')\Big)\\
# &=\operatorname{Cov}\left(\int_a^x f(t)\,dt,\int_a^{x'} f(s)\,ds\right)\\
# &=\int_a^x\int_a^{x'}\operatorname{Cov}\big(f(t),f(s)\big)\,ds\,dt\\
# &=\int_a^x\int_a^{x'}k(t,s)\,ds\,dt.
# \end{aligned}
# $$
#
# ---
#
# Therefore, the integrated process satisfies
#
# $$
# F(x)\sim\mathcal{GP}\left(M(x),K(x,x')\right),
# $$

# %% [markdown]
# > These expressions form the basis of **Bayesian Quadrature**, where integration is treated as a probabilistic inference problem and uncertainty over the integral is quantified directly through the Gaussian Process posterior.
# > We now incorporate observations
# > $$
# > \mathcal{D} = {(x_i, y_i)}_{i=1}^n,\quad y_i = f(x_i),
# > $$
# > which induce the posterior process. All results for the integrated process carry over directly by replacing prior moments with posterior ones:
# > $$
# > m(x) \rightarrow \bar{f}*{f|\mathbf{D}}(x),\qquad
# > k(x,x') \rightarrow \mathrm{Cov}*{f|\mathbf{D}}(f(x), f(x')).
# > $$

# %% [markdown]
# ### 1.B

# %% [markdown]
# We now extend the Gaussian Process framework to the case of Bayesian Quadrature, where the object of interest is not the function itself, but its integral over a domain, allowing expectations of nonlinear functions to be computed in a principled probabilistic manner.
#
# ---
#
# **Posterior mean function:**
#
# $$
# \begin{aligned}
# \mathbb{E}_{f|\mathbf{D}}[F(x)]
#      &= \mathbb{E}_{f|\mathbf{D}}\left[\int f(t)p(t)\, dt\right] \\
#      &= \int \mathbb{E}_{f|\mathbf{D}}[f(t)] p(t)\, dt \\
#      &= \int \left[ \int_F f(t) p(f|\mathbf{D}) df \right] p(t)\, dt\\
#      &= \int \bar{f}_{f|\mathbf{D}}(t) p(t)\, dt
# \end{aligned}
# $$
#
# Using the partitioned Gaussian result from before:
#
# $$
# \boldsymbol{\mu}_{\mathbf{f}_* | \mathbf{f}} = \boldsymbol{\mu}_2 + \Sigma_{21} \Sigma_{11}^{-1} (\mathbf{x}_1 - \boldsymbol{\mu}_1)
# $$
#
# The posterior **mean of $f$** is:
#
# $$
# \bar{f}_{f|\mathbf{D}}(t) = m(t) + k(t,X) k(X,X)^{-1} \Big( f(X) - m(X) \Big)
# $$
#
# Substituting gives:
#
# $$
# \begin{aligned}
# \mathbb{E}_{f|\mathbf{D}}[F(x)]
#     &= \int \Big[m(t) + k(t, X) k(X, X)^{-1} \Big( f(X) - m(X) \Big)\Big] p(t)\, dt \\
#     &= \int m(t)p(t)\, dt + \int_a^x k(t, X) k(X, X)^{-1} \Big( f(X) - m(X) \Big)p(t)\, dt \\
#     &= M(x) + \underbrace{\left[ \int_a^x k(t, X)p(t)\, dt \right]}_{\mathbf{k}_F} k(X, X)^{-1} \Big( f(X) - m(X) \Big) \\
# \end{aligned}
# $$
#
# ---
#
# **Posterior covariance function:**
#
# $$
# \begin{aligned}
# \text{Cov}_{f|\mathbf{D}}\left(F(x), F(x')\right)
#          &=\text{Cov}_{f|\mathbf{D}}\left(\int f(t)p(t)\, dt, \int f(s)p(s)\, ds\right) \\
#          &= \int_a^x \int \text{Cov}_{f|\mathbf{D}}\Big(f(t)p(t), f(s)p(s)\Big)\, ds\, dt \\
#          &= \int_a^x \int \text{Cov}_{f|\mathbf{D}}\Big(f(t), f(s)\Big)p(s)p(t)\, ds\, dt \\
# \end{aligned}
# $$
#
# Using the partitioned Gaussian result from before:
#
# $$
# \boldsymbol{\Sigma}_{\mathbf{f}_* | \mathbf{f}} = \Sigma_{22} - \Sigma_{21} \Sigma_{11}^{-1} \Sigma_{12}
# $$
#
# The posterior **covariance function of $f$** is:
#
# $$
# \text{Cov}_{f|\mathbf{D}}\Big(f(t), f(s)\Big) = k(t,s) - k(t,X) k(X,X)^{-1} k(X,s)
# $$
#
# Substituting gives:
#
# $$
# \begin{aligned}
# \text{Cov}_{f|\mathbf{D}}\left(F(x), F(x')\right)
#         &= \int_a^x \int_a^{x'} \Big[ k(t, s) - k(t, X) k(X, X)^{-1} k(X, s) \Big] p(s)p(t)\, ds\, dt \\
#         &= \int_a^x \int_a^{x'} k(t, s)p(t)p(s)\, ds\, dt \\
#         &\quad - \int_a^x \int_a^{x'} k(t, X) k(X, X)^{-1} k(X, s) p(s)p(t)\, ds\, dt \\
#         &= K(x,x') - \int_a^x \int_a^{x'} \Big[ k(t, X)p(t)\Big] k(X, X)^{-1} \Big[ k(X, s)p(s) \Big]\, ds\, dt \\
# \end{aligned}
# $$
#
# ---
#
# Putting everything together, we obtain the compact Bayesian Quadrature expressions:
#
# $$
# \boxed{\mathbb{E}_{f|\mathbf{D}}[F(x)] = M(x) + \mathbf{k}_F^T(x) K^{-1} \Big(f(X)-m(X) \Big)}
# $$
#
# $$
# \boxed{\text{Cov}_{f|\mathbf{D}}\left(F(x), F(x')\right) = K(x,x') - \mathbf{k}_F^T(x) K^{-1} \mathbf{k}_F(x')}
# $$
#
# where
#
# $$
# \mathbf{k}_F(x) = \Big[ \int_a^x k(t, x_1)p(t)\, dt,\; \int_a^x k(t, x_2)p(t)\, dt,\; \cdots ,\; \int_a^x k(t, x_n)p(t)\, dt \Big]
# $$
#
# and $K = k(X,X)$ is the Gram matrix of the training inputs under the kernel $k$.
#
# ---
#
# This formulation shows that Bayesian Quadrature reduces integration to standard Gaussian Process inference, with integrals appearing naturally through kernel mean embeddings.

# %% [markdown]
# > Before introducing any probability measure, we return to the **Gaussian Process prior** and consider the kernel integrals in isolation. This provides the cleanest setting in which to understand the structure of the integrated kernel, without any additional weighting over the domain.
# >
# > At this stage, we work directly with the unweighted integral process
# > $$
# > F(x) = \int_a^x f(t),dt
# > $$
# > and focus on deriving closed-form expressions for the corresponding kernel integrals.
# >
# > In later sections, this construction will be generalised first to a **Gaussian measure over the integration domain**, and subsequently to a **Gaussian mixture measure**, from which the full Bayesian Quadrature framework naturally emerges.

# %% [markdown]
# ### 1.C

# %% [markdown]
# We now derive the kernel integrals required for Bayesian Quadrature in the simplest setting, working directly from the Gaussian Process prior without introducing any probability measure. The goal is to obtain closed-form expressions for the integral of the kernel and its associated second-order term, which fully characterise the mean and uncertainty of the integrated process.
#
# Lets start by deriving the mean of the integral
#
# Using RBF Kernel $k(y,x) = \sigma_f^2\exp \left(-\frac{1}{2l^2} |x-y|^2 \right)$:
# $$
# \begin{aligned}
# v[k] &= \int_a^x k(t,s) dt \\
#      &= \int_a^x \sigma_f^2\exp \left(-\frac{1}{2l^2} |s-t|^2 \right) dt \\
# \end{aligned}
# $$
# Let $l = \sigma$ hereon and factor out $\sigma_f^2 \cdot \sigma \sqrt{2\pi}$:
# $$
# \begin{aligned}
# v[k] &= \sigma_f^2 \cdot \sigma \sqrt{2\pi} \int_a^x \frac{1}{\sigma\sqrt{2\pi}}\exp \left(-\frac{(s-t)^2}{2\sigma^2} \right) dt \\
#      &= \sigma_f^2 \cdot \sigma \sqrt{2\pi} \int_a^x k^*(t,s) dt \\
# \end{aligned}
# $$
# Now working with just $k^*(t,s)$:
# $$
# \begin{aligned}
# v^*[k] &= \int_a^x \frac{1}{\sigma\sqrt{2\pi}}\exp \left(-\frac{(s-t)^2}{2\sigma^2} \right) dt \\
#      &= \frac{1}{2} \left[1+\text{erf} \left(\frac{x-s}{\sigma\sqrt{2}} \right) \right] - \frac{1}{2} \left[1+\text{erf} \\ \left(\frac{a-s}{\sigma\sqrt{2}} \right) \right] \\
#      &= \frac{1}{2} \left[ \text{erf} \left(\frac{x-s}{\sigma\sqrt{2}} \right) - \text{erf}\left(\frac{a-s}{\sigma\sqrt{2}} \right) \right] \\
# \end{aligned}
# $$
#
# ---
#
# For the uncertainty we have to integrate again.
#
# $$
# \begin{aligned}
# vv[k] &= \int_a^x \int_a^x k(t,s) dsdt \\
#       &= \sigma_f^2 \cdot \sigma \sqrt{2\pi} \int_a^x \int_a^x k^*(t,s) dtds \\
#       &= \sigma_f^2 \cdot \sigma \sqrt{2\pi} \int_a^x \frac{1}{2}\text{erf} \left(\frac{x-s}{\sigma\sqrt{2}} \right) - \frac{1}{2}\text{erf} \left(\frac{a-s}{\sigma\sqrt{2}} \right)ds \\
# \end{aligned}
# $$
#
# Focusing on just $k^*(t,s)$, let $u_1 = \frac{x-s}{\sigma\sqrt{2}}$ and $u_2 = \frac{a-s}{\sigma\sqrt{2}}$
#
# $\implies$ $du_1 = du_2 = du = \frac{-1}{\sigma\sqrt{2}} \cdot ds$
#
# $\implies$ $ds = -\sigma\sqrt{2} \cdot du$
#
# $$
# \begin{aligned}
# vv^*[k] &= \int_a^x \frac{1}{2}\text{erf}(u_1)ds - \int_a^x\frac{1}{2}\text{erf}(u_2)ds \\
#        &= \int_{\frac{x-a}{\sigma\sqrt{2}}}^0 -\frac{1}{2}\text{erf}(u_1) \cdot \sigma\sqrt{2} \cdot du_1 - \int_0^{\frac{a-x}{\sigma\sqrt{2}}} - \frac{1}{2}\text{erf}(u_2) \cdot \sigma\sqrt{2} \cdot du_2 \\
#        &= \int_0^{\frac{x-a}{\sigma\sqrt{2}}} \frac{1}{2}\text{erf}(u) \cdot \sigma\sqrt{2} \cdot du - \int_{\frac{a-x}{\sigma\sqrt{2}}}^0 \frac{1}{2}\text{erf}(u) \cdot \sigma\sqrt{2} \cdot du \\
#        &= \frac{\sigma\sqrt{2}}{2} \left(\int_0^{\frac{x-a}{\sigma\sqrt{2}}} \text{erf}(u)du + \int_0^{\frac{x-a}{\sigma\sqrt{2}}} \text{erf}(u)du \right) \\
#        &= \sigma\sqrt{2} \left(\int_0^{\frac{x-a}{\sigma\sqrt{2}}} \text{erf}(u)du \right) \\
# \end{aligned}
# $$
#
# Using $\int_0^\theta \text{erf}(u)du = \theta \, \text{erf}(\theta) + \frac{e^{-\theta^2} - 1}{\sqrt{\pi}}$, Let $\theta = \frac{x-a}{\sigma\sqrt{2}}$:
#
# $$
# \begin{aligned}
# vv^*[k] &= \sigma\sqrt{2} \left(\theta \, \text{erf}(\theta) + \frac{e^{-\theta^2} - 1}{\sqrt{\pi}} \right) \\
#         &= (x-a) \, \text{erf} \left( \frac{x-a}{\sigma \sqrt{2}} \right) + \sigma\sqrt{2} \left( \frac{\exp{\left(-{\frac{(x-a)^2}{2 \sigma^2}}\right)} - 1}{\sqrt{\pi}} \right)\\
# \end{aligned}
# $$
#
# ---
#
# So we have:
# $$
# \begin{align*}
# v[k] &= \left( \sigma_f^2 \cdot \sigma \sqrt{2\pi} \right) v^*[k] \\
#      &= \left( \sigma_f^2 \cdot \sigma \sqrt{2\pi} \right) \, \left[\frac{1}{2} \text{erf} \left(\frac{x-s}{\sigma\sqrt{2}} \right) - \frac{1}{2} \text{erf}\left(\frac{a-s}{\sigma\sqrt{2}} \right) \right] \\
#      \\
# vv[k] &= \left( \sigma_f^2 \cdot \sigma \sqrt{2\pi} \right) vv^*[k] \\
#       &= \left( \sigma_f^2 \cdot \sigma \sqrt{2\pi} \right) \left[(x-a) \, \text{erf} \left( \frac{x-a}{\sigma \sqrt{2}} \right) + \sigma\sqrt{2} \left( \frac{\exp{\left(-{\frac{(x-a)^2}{2 \sigma^2}}\right)} - 1}{\sqrt{\pi}} \right) \right] \\
#       &= \sigma_f^2 \left[ \sigma \sqrt{2\pi} \, (x-a) \, \text{erf} \left( \frac{x-a}{\sigma \sqrt{2}} \right) + 2 \sigma^2 \left( e^{-{\frac{(x-a)^2}{2 \sigma^2}}} - 1 \right) \right] \\
# \end{align*}
# $$

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### 2.A

# %% [markdown]
# #### Integrating a Function $f(t)$ with respect to probability measure $p(t)$
#
# Let
#
# $$
# f \sim \mathcal{GP}(m(x), k(x,x')),
# $$
#
# where $m(x)$ is the mean function and $k(x,x')$ is the covariance kernel of the Gaussian Process.
#
# Consider the integral process under a probability measure $p(t)$:
#
# $$
# \begin{aligned}
# F(x) &= \int_a^x f(t)\, d\mathbb{P}(t) \\
#      &= \int_a^x f(t)\, p(t)\, dt
# \end{aligned}
# $$
#
# Since Gaussian processes are closed under linear operations, and integration against a fixed weighting function $p(t)$ is a linear functional of $f(t)$, the resulting process $F(x)$ remains Gaussian. Consequently, $F(x)$ is itself a Gaussian Process, and its mean and covariance can be derived analytically in closed form by propagating the kernel through the integral operator.
#
# ---
#
# **Prior mean function:**
#
# $$
# \begin{aligned}
# M(x) &= \mathbb{E}[F(x)] \\
#       &= \mathbb{E}\left[\int_a^x f(t)p(t) dt\right] \\
#       &= \int_a^x \mathbb{E}[f(t)] p(t) dt \\
#       &= \int_a^x m(t) p(t)dt
# \end{aligned}
# $$
#
#
# **Prior covariance function:**
#
# $$
# \begin{aligned}
# K(x,x') &= \text{Cov}\Big(F(x), F(x')\Big) \\
#         &= \text{Cov}\left(\int_a^x f(t) p(t) dt , \int_a^{x'} f(s) p(s) ds\right) \\
#         &= \int_a^x \int_a^{x'} \text{Cov}\Big(f(t), f(s)\Big)p(s)p(t)\, ds\, dt \\
#         &= \int_a^x \int_a^{x'} k(t,s) p(s)p(t)\, ds\, dt \\
# \end{aligned}
# $$
#
# ---
#
# Therefore, the integrated process satisfies
#
# $$
# F(x)\sim\mathcal{GP}\left(M(x),K(x,x')\right),
# $$

# %% [markdown]
# > We now express the integrated posterior quantities more generally by taking the mean and kernel functions under a probability measure over the integration domain.

# %% [markdown]
# ### 2.B

# %% [markdown]
# Lets start by deriving the mean of the integral
#
#
# For now, we use RBF isotropic kernel $k(\mathbf{y},\mathbf{x}) = \sigma_f^2\exp \left(-\frac{1}{2l^2} ||\mathbf{x}-\mathbf{y}||^2 \right)$:
#
# Looking at the univariate case for now:
# $$
# \begin{aligned}
# v[k] &= \int_a^x k(t,s)p(t) dt \\ &= \int_a^x \sigma_f^2 \exp \left(-\frac{1}{2l^2} (s-t)^2 \right) \frac{1}{\sigma_p \sqrt
#         {2 \pi}} \exp\left( -\frac{1}{2 \sigma_p^2}(t - \mu_p)^2 \right) dt \\
#      &= \sigma_f^2 l \sqrt{2 \pi} \int_a^x \frac{1}{l \sqrt{2 \pi}} \exp \left(-\frac{1}{2l^2} (s-t)^2 \right) \frac{1}
#         {\sigma_p \sqrt{2 \pi}} \exp\left(-\frac{1}{2 \sigma_p^2}(t - \mu_p)^2 \right) dt \\
#         &= \sigma_f^2 l \sqrt{2 \pi} \, \mathcal{N}(t | s, l^2)\,\mathcal{N}(t | \mu_p, \sigma_p^2) \\
# \end{aligned}
# $$
#
# At this point, the problem reduces to the product of two Gaussian densities, which admits a closed-form simplification.
#
# Using result A.7 in *Carl Edward Rasmussen & Christopher K. I. Williams (2006)*:
#
# The product of two Gaussians gives another (un-normalized) Gaussian
# $$
# \mathcal{N}(x | a, A)\,\mathcal{N}(x | b, B)
# = Z^{-1}\,\mathcal{N}(x | c, C)
# $$
# where
# $$
# \mathbf{c} = \mathbf{C}\,(A^{-1}a + B^{-1}b),
# \qquad
# C = \left(A^{-1} + B^{-1}\right)^{-1}
# $$
#
# The normalizing constant looks itself like a Gaussian
#
# $$
# Z^{-1} = (2\pi)^{-D/2} \, |A + B|^{-1/2} \,
# \exp\left(-\tfrac{1}{2}(a-b)^T(A+B)^{-1}(a-b)\right)
# $$
#
# Applying the result:
#
# $$
# \mathbf{c} = \mathbf{C}\,((l^2)^{-1} s + (\sigma_p^2)^{-1} \mu_p),
# \qquad
# C = \left((l^2)^{-1} + (\sigma_p^2)^{-1}\right)^{-1}
# $$
#
# The normalizing constant looks itself like a Gaussian
#
# $$
# \begin{aligned}
# Z^{-1} &= (2\pi)^{-1/2} \, |(l^2) + (\sigma_p^2)|^{-1/2} \, \exp\left(-\tfrac{1}{2}(s-\mu_p)^T((l^2)+(\sigma_p^2))^{-1}(s-\mu_p)\right) \\
# &= \frac{1}{\sqrt{2\pi \, (l^2 + \sigma_p^2)}} \, \exp\left(-\frac{(s-\mu_p)^2}{2(l^2+\sigma_p^2)}\right) \\
# \end{aligned}
# $$
#
# And finally:
# $$
# \begin{aligned}
# v[k] &= \sigma_f^2 l \sqrt{2 \pi} \, \mathcal{N}(t | s, l^2)\,\mathcal{N}(t | \mu_p, \sigma_p) \\
#      &= \sigma_f^2 l \sqrt{2 \pi} \, \frac{1}{\sqrt{2\pi \, (l^2 + \sigma_p^2)}} \, \exp\left(-\frac{(s-\mu_p)^2}{2(l^2+\sigma_p^2)}\right) \\
#      &= \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + \sigma_p^2}}\, \exp\left(-\frac{(s-\mu_p)^2}{2(l^2+\sigma_p^2)}\right) \\
# \end{aligned}
# $$
#
# ---
#
# For the uncertainty we have to integrate again. We will again use $[a,x] = [-\infty, \infty]$.
#
# $$
# \begin{aligned}
# vv[k] &= \int \int k(t,s)p(t)p(s) dtds \\
#       &= \int \Big[\int k(t,s)p(t) dt\Big] \,p(s)ds \\
#       &= \int v[k] \,p(s)ds \\
#       &= \int \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + \sigma_p^2}}\, \exp\left(-\frac{(s-\mu_p)^2}{2(l^2+\sigma_p^2)}\right) ds \, \mathcal{N}(s | \mu_p, \sigma_p^2) \\
#       &= \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \sqrt{(2\pi) (\sigma_p^2 + l^2)} \int \frac{1}{\sqrt{(2\pi) (\sigma_p^2 + l^2)}}\exp\left(-\frac{(s-\mu_p)^2}{2(l^2+\sigma_p^2)}\right) ds \, \mathcal{N}(s | \mu_p, \sigma_p^2) \\
#       &= \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \sqrt{(2\pi) (\sigma_p^2 + l^2)} \, \mathcal{N}(s | \mu_p, \sigma_p^2 + l^2) \, \mathcal{N}(s | \mu_p, \sigma_p^2)\\
# \end{aligned}
# $$
#
# Using the earlier A.7 result:
#
# $$
# Z^{-1} = (2\pi)^{-1/2} \, (2\sigma_p^2 + l^2)^{-1/2}
# $$
#
# We then have:
# $$
# \begin{aligned}
# vv[k] &= \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \sqrt{(2\pi) (\sigma_p^2 + l^2)} \, \mathcal{N}(s | \mu_p, \sigma_p^2 + l^2) \, \mathcal{N}(s | \mu_p, \sigma_p^2)\\
#       &= \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \sqrt{(2\pi) (\sigma_p^2 + l^2)} \, (2\pi)^{-1/2} \, (2\sigma_p^2 + l^2)^{-1/2} \\
#       &= \sigma_f^2 \, \sqrt{\frac{l^2}{l^2 + 2\sigma_p^2}}  \\
# \end{aligned}
# $$
#
# ---

# %% [markdown]
# ### 2.C

# %% [markdown]
# #### Mixture case
#
# We now extend the previous Gaussian setting to the case where the input distribution is given by a **Gaussian mixture model (GMM)**. This allows Bayesian Quadrature to handle multimodal uncertainty by decomposing the integral into a weighted sum over individual Gaussian components.
#
# Suppose instead that the distribution over $s$ is a mixture of Gaussians:
#
# $$
# p_{\text{mix}}(t) = \sum_{j=1}^J w_j\, \mathcal{N}(t | \mu_j, \sigma_j^2),
# \quad \text{with } \sum_j w_j = 1, \; w_j \ge 0.
# $$
#
# Because integration is linear, the cross-covariance between kernel $k(s,t)$ and the mixture is simply
#
# $$
# v_{\text{mix}}[k]
# = \int k(s,t)\, p_{\text{mix}}(t)\,dt
# = \sum_{j=1}^J w_j \int k(s,t) \,\mathcal{N}(t | \mu_j,\sigma_j^2)\,dt.
# $$
#
# So,
#
# $$
# v_{\text{mix}}[k] = \sum_{j=1}^J w_j\, v_j[k],
# $$
#
# where $v_j[k]$ is the formula derived earlier for the single Gaussian case.
#
# ---
#
# The variance term is the expectation of the kernel under two independent draws from $p_{\text{mix}}$:
#
# $$
# vv_{\text{mix}}[k]
# = \iint k(s,t)\, p_{\text{mix}}(s)\,p_{\text{mix}}(t)\,ds\,dt.
# $$
#
# Expanding the mixture structure gives
#
# $$
# vv_{\text{mix}}[k]
# = \iint k(s,t) \Bigg(\sum_{i=1}^J w_i \,\mathcal{N}(s | \mu_i,\sigma_i^2)\Bigg)
# \Bigg(\sum_{j=1}^J w_j \,\mathcal{N}(t | \mu_j,\sigma_j^2)\Bigg)\,ds\,dt.
# $$
#
# Rewriting as a double sum:
#
# $$
# vv_{\text{mix}}[k]
# = \sum_{i=1}^J \sum_{j=1}^J w_i w_j
# \iint k(s,t) \,\mathcal{N}(s | \mu_i,\sigma_i^2)\,\mathcal{N}(t | \mu_j,\sigma_j^2)\,ds\,dt.
# $$
#
# Each term
#
# $$
# I_{ij} = \iint k(s,t) \,\mathcal{N}(s | \mu_i,\sigma_i^2)\,\mathcal{N}(t | \mu_j,\sigma_j^2)\,ds\,dt
# $$
#
# represents the kernel expectation under two Gaussian components.
#
# $$
# I_{ij} = \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_i^2 + \sigma_j^2}}
# \exp\!\left(-\frac{(\mu_i-\mu_j)^2}{2(l^2 + \sigma_i^2 + \sigma_j^2)}\right).
# $$
#
# Which follows directly from the same Gaussian product identities used in the single-Gaussian case.
#
# ---
#
# Finally, collecting results:
#
# $$
# v_{\text{mix}}[k] = \sum_{j=1}^J w_j\, v_j[k],
# $$
#
# $$
# vv_{\text{mix}}[k] = \sum_{i=1}^J \sum_{j=1}^J w_i w_j\, I_{ij},
# $$
#
# with:
#
# $$
# I_{ij} = \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_i^2 + \sigma_j^2}}
# \exp\!\left(-\frac{(\mu_i-\mu_j)^2}{2(l^2 + \sigma_i^2 + \sigma_j^2)}\right).
# $$
#
# ---

# %% [markdown]
# ## Section 3

# %% [markdown]
# ### 3.A

# %% [markdown]
# We now extend the previous univariate derivations to the multivariate setting, where the input is distributed according to a Gaussian density and the kernel is replaced by its full anisotropic (ARD) form. The structure of the derivation closely mirrors Section **2.B**, with the key difference being the transition from scalar to matrix-valued quantities.
#
# Let us begin by deriving the mean of the integral.
#
# We will use the anisotropic Gaussian kernel
# $$
# k(\mathbf{y}, \mathbf{x}) = \sigma_f^2 \exp\Big[-\frac{1}{2} (\mathbf{x}-\mathbf{y})^T \mathbf{L}^{-2} (\mathbf{x}-\mathbf{y}) \Big],
# $$
# commonly referred to as the ARD Gaussian kernel when
# $\mathbf{L}^{-2} = \mathrm{diag}(l_1^{-2}, \dots, l_d^{-2})$.
#
# $$
# \begin{aligned}
# v[k] &= \int k(\mathbf{t},\mathbf{s})p(\mathbf{t}) d\mathbf{t} \\
#      &= \int \sigma_f^2 \exp\Big[-\frac{1}{2} (\mathbf{t}-\mathbf{s})^T \mathbf{L}^{-2} (\mathbf{t}-\mathbf{s}) \Big]
#         \frac{1}{\sqrt{(2\pi)^d |\Sigma_p|}}
#         \exp\Big[-\frac{1}{2} (\mathbf{t}-\boldsymbol{\mu}_p)^T \Sigma_p^{-1} (\mathbf{t}-\boldsymbol{\mu}_p)\Big] d\mathbf{t} \\
# \end{aligned}
# $$
#
# As in the univariate case, this reduces to a product of two Gaussian densities. The key observation is that the integrand is proportional to a Gaussian in $\mathbf{t}$, allowing the same completion-of-the-square argument used in Section **2.B**.
#
# $$
# \begin{aligned}
# v[k] &= \sigma_f^2 \sqrt{(2\pi)^d |\mathbf{L^2}|}
# \int \mathcal{N}(\mathbf{t} \mid \mathbf{s}, \mathbf{L}^2) \, \mathcal{N}(\mathbf{t} \mid \boldsymbol{\mu}_p, \Sigma_p) \, d\mathbf{t}.
# \end{aligned}
# $$
#
# Using result A.7 in *Carl Edward Rasmussen & Christopher K. I. Williams (2006)*:
#
# The product of two Gaussians gives another (unnormalised) Gaussian
# $$
# \mathcal{N}(x | a, A)\,\mathcal{N}(x | b, B)
# = Z^{-1}\,\mathcal{N}(x | c, C)
# $$
#
# where
# $$
# \mathbf{c} = \mathbf{C}\,(A^{-1}a + B^{-1}b),
# \qquad
# C = \left(A^{-1} + B^{-1}\right)^{-1}.
# $$
#
# Applying this directly:
#
# $$
# \mathbf{C} = \Big(\mathbf{L^2}^{-1} + \Sigma_p^{-1}\Big)^{-1}
# $$
#
# $$
# \mathbf{c} = \mathbf{C} \Big(\mathbf{L^2}^{-1} \mathbf{s} + \Sigma_p^{-1} \boldsymbol{\mu}_p \Big)
# $$
#
# $$
# Z^{-1} = (2\pi)^{-d/2} |\Sigma_p + \mathbf{L^2}|^{-1/2}
# \exp\Big[-\frac{1}{2} (\mathbf{s}-\boldsymbol{\mu}_p)^T (\Sigma_p + \mathbf{L^2})^{-1} (\mathbf{s}-\boldsymbol{\mu}_p) \Big]
# $$
#
# Since the remaining Gaussian integrates to one, only the normalisation term contributes:
#
# $$
# \begin{aligned}
# v[k] &= \sigma_f^2 (2\pi)^{d/2} |\mathbf{L}| Z^{-1} \\
#      &= \sigma_f^2 |\mathbf{L}| |\Sigma_p + \mathbf{L^2}|^{-1/2}
#         \exp\Big[-\frac{1}{2} (\mathbf{s}-\boldsymbol{\mu}_p)^T (\Sigma_p + \mathbf{L^2})^{-1} (\mathbf{s}-\boldsymbol{\mu}_p) \Big].
# \end{aligned}
# $$
#
# For the uncertainty term we proceed analogously to Section **2.B**, performing a second integration over the Gaussian measure:
#
# $$
# \begin{aligned}
# vv[k] &= \int \int k(t,s)p(t)p(s) dtds \\
#       &= \int v[k] \,p(s)ds.
# \end{aligned}
# $$
#
# Substituting the expression for $v[k]$ and repeating the Gaussian-product argument yields:
#
# $$
# \begin{aligned}
# vv[k]
# &= \sigma_f^2 |\mathbf{L}| |\Sigma_p + \mathbf{L^2}|^{-1/2} \sqrt{(2\pi)^d |\Sigma_p + \mathbf{L^2}|} \, \mathcal{N}(s | \mu_p, \Sigma_p + \mathbf{L^2}) \, \mathcal{N}(s | \mu_p, \Sigma_p).
# \end{aligned}
# $$
#
# Using the same identity as before:
#
# $$
# Z^{-1} = (2\pi)^{-d/2} \, |[\Sigma_p + \mathbf{L^2}] + \Sigma_p|^{-1/2}
# $$
#
# we obtain the final closed form:
#
# $$
# \begin{aligned}
# vv[k]
# &= \sigma_f^2 |\mathbf{L}| \, |2\Sigma_p + \mathbf{L^2}|^{-1/2}.
# \end{aligned}
# $$
#
# Similarly as in Section **2.C**, under a Gaussian mixture measure:
#
# $$
# v_{\text{mix}}[k] = \sum_{j=1}^J w_j\, v_j[k],
# $$
#
# $$
# vv_{\text{mix}}[k] = \sum_{i=1}^J \sum_{j=1}^J w_i w_j\, I_{ij},
# $$
#
#
# where:
# $$
# I_{ij}
# = \sigma_f^2|\mathbf{L}| \big|\Sigma_i+\Sigma_j+\mathbf{L}^2\big|^{-1/2}
# \exp\Big(-\tfrac{1}{2}(\boldsymbol\mu_i-\boldsymbol\mu_j)^T(\Sigma_i+\Sigma_j+\mathbf{L}^2)^{-1}(\boldsymbol\mu_i-\boldsymbol\mu_j)\Big).
# $$
#
# The key structure remains unchanged: the Gaussian nature of both kernel and measure ensures all integrals collapse to closed-form expressions involving only covariance sums and determinants.

# %% [markdown]
# ## Section 4

# %% [markdown]
# This section shows derivations associated with the negative quadratc mean function, a common choice for priors using GPs in VBMC.
#
# > The negative quadratic decays to $-\infty$ in every direction away from the centre, which serves two purposes.
# >
# > **1 · Integrability — keeps the ELBO finite**
# > For the ELBO's expectation term (computed via Bayesian quadrature) to be well-defined, the integral of $\exp(\text{GP mean})$ over the input space must converge. A negative quadratic prior guarantees this; a flat or constant mean does not.
# >
# > **2 · Acquisition guidance — repels search from the periphery**
# > In unexplored regions far from observations, the surrogate predicts implausibly low log-likelihood values. Acquisition functions that incorporate the GP mean are then naturally pulled toward regions that are both *uncertain* and *plausibly relevant* — not just uncertain.

# %% [markdown]
# ### 4.A

# %% [markdown]
# #### Integrating mean function (Univariate)
#
# We begin by integrating the Gaussian Process mean function under a univariate Gaussian mixture measure. In this case, a negative quadratic mean function is used:
#
# $$
# m(t) = m_0 - \frac{1}{2}\frac{(t-x_m)^2}{w^2}.
# $$
#
# The integrated mean is therefore
#
# $$
# M = \int m(t) p(t)dt = \int \Big[m_0 - \frac{1}{2}\frac{(t-x_m)^2}{w^2}\Big] \sum_{k=1}^K \pi_k \mathcal{N}(t \mid \mu_k, \sigma_k^2) dt
# $$
#
# Using linearity of integration, we first distribute the integral over the Gaussian mixture components:
#
# $$
# M = \sum_{k=1}^K \pi_k \int \Big[m_0 - \frac{1}{2}\frac{(t-x_m)^2}{w^2}\Big] \mathcal{N}(t \mid \mu_k, \sigma_k^2) dt
# $$
#
# We then separate the constant and quadratic terms:
#
# $$
# M =   \Bigg[m_0 \underbrace{\int \sum_{k=1}^K \pi_k \mathcal{N}(t \mid \mu_k, \sigma_k^2) dt}_{=1} - \frac{1}{2 w^2} \underbrace{\int (t-x_m)^2 \mathcal{N}(t \mid \mu_k, \sigma_k^2) dt}_{\sigma_k^2 + (\mu_k - x_m)^2} \Bigg]
# $$
#
# Using the second moment identity for a Gaussian random variable yields the closed-form result
#
# $$
# \boxed{
# M = m_0 - \frac{1}{2 w^2} \sum_{k=1}^K \pi_k \big[ (\mu_k - x_m)^2 + \sigma_k^2 \big]
# }
# $$
#
# ---

# %% [markdown]
# ### 4.B

# %% [markdown]
# #### Integrating mean function (Multivariate)
#
# We now extend the integrated mean derivation to the multivariate setting under a Gaussian mixture measure. As in the univariate case, a negative quadratic Gaussian Process mean function is used:
#
# $$
# m(\mathbf{x}) = m_0 - \frac{1}{2} (\mathbf{t} - \mathbf{x}_m)^T W^{-2} (\mathbf{t} - \mathbf{x}_m)
# $$
#
# where $W = \mathrm{diag}(w_1, \dots, w_d)$.
#
# The multivariate Gaussian mixture density is given by
#
# $$
# p(\mathbf{x}) = \sum_{k=1}^K \pi_k \, \mathcal{N}(\mathbf{t} \mid \boldsymbol{\mu}_k, \Sigma_k)
# $$
#
# The integrated mean therefore becomes
#
# $$
# M = \int m(\mathbf{t})p(\mathbf{t})d\mathbf{x} = \sum_{k=1}^K \pi_k \int \Big[ m_0 - \frac{1}{2} (\mathbf{t} - \mathbf{x}_m)^\top W^{-2} (\mathbf{t} - \mathbf{x}_m) \Big] \mathcal{N}(\mathbf{t}\mid \boldsymbol{\mu}_k, \Sigma_k)d\mathbf{t}
# $$
#
# Separating the constant and quadratic contributions gives
#
# $$
# M = \sum_{k=1}^K \pi_k \Bigg[ m_0 - \frac{1}{2} \underbrace{\int (\mathbf{t} - \mathbf{x}_m)^\top W^{-2} (\mathbf{t} - \mathbf{x}_m) \mathcal{N}(\mathbf{t} \mid \boldsymbol{\mu}_k, \Sigma_k) d\mathbf{x}}_{\text{expectation of quadratic form}} \Bigg]
# $$
#
# For a multivariate Gaussian random vector
# $\mathbf{x} \sim \mathcal{N}(\boldsymbol{\mu}_k, \Sigma_k)$, the expectation of the quadratic form is
#
# $$
# \mathbb{E}[ (\mathbf{x} - \mathbf{x}_m)^T W^{-2} (\mathbf{x} - \mathbf{x}_m) ] = \operatorname{tr}( W^{-2} \Sigma_k ) + (\boldsymbol{\mu}_k - \mathbf{x}_m)^T W^{-2} (\boldsymbol{\mu}_k - \mathbf{x}_m)
# $$
#
# Substituting this result yields the closed-form expression for the integrated multivariate mean function:
#
# $$
# \boxed{
# M = m_0 - \frac{1}{2} \sum_{k=1}^K \pi_k \Big[ (\boldsymbol{\mu}_k - \mathbf{x}_m)^T W^{-2} (\boldsymbol{\mu}_k - \mathbf{x}_m) + \operatorname{tr}(W^{-2} \Sigma_k) \Big]
# }
# $$
#
# ---

# %% [markdown]
# ## Section 5

# %% [markdown]
# ### 5.A

# %% [markdown]
# #### Product of 2 gaussians
#
# This section provides an additional standalone derivation of the closed-form kernel integrals previously used throughout the notebook. In particular, the proof shows how the product of the RBF kernel and a Gaussian density can itself be rewritten as a Gaussian, yielding analytic expressions for both the Bayesian Quadrature mean term $v[k]$ and the integrated uncertainty term $vv[k]$.
#
# $$
# \begin{aligned}
# v[k] &= \int_a^x k(t,s)p(t) dt \\
#      &= \int_a^x \sigma_f^2 \exp \left(-\frac{1}{2l^2} (s-t)^2 \right) \frac{1}{\sigma_p \sqrt{2 \pi}} \exp\left(
#      -\frac{1}{2 \sigma_p^2}(t - \mu_p)^2 \right) dt \\
#      &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left(-\frac{1}{2l^2} (s-t)^2  -\frac{1}{2 \sigma_p^2}(t - \mu_p)^2 \right) dt \\
#      &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left(-\frac{1}{2l^2} \left(s^2-2st+t^2\right)  -\frac{1}{2 \sigma_p^2}\left(t^2 - 2t\mu_p + \mu_p^2\right) \right) dt \\
#      &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left( -\frac{1}{2} \left[ \left(\frac{1}{l^2} + \frac{1}{\sigma_p^2}\right) t^2 - 2\left(\frac{s}{l^2} + \frac{\mu_p}{\sigma_p^2}\right) t + \left(\frac{s^2}{l^2} + \frac{\mu_p^2}{\sigma_p^2}\right) \right] \right)dt \\
#      &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left(-\frac{1}{2} \left(\frac{1}{l^2} + \frac{1}{\sigma_p^2}\right) \left[ \left( t^2 - 2 \frac{\frac{s}{l^2} + \frac{\mu_p}{\sigma_p^2}}{\frac{1}{l^2} + \frac{1}{\sigma_p^2}} t \right) + \frac{\frac{s^2}{l^2} + \frac{\mu_p^2}{\sigma_p^2}}{\frac{1}{l^2} + \frac{1}{\sigma_p^2}} \right]\right)dt \\
# \end{aligned}
# $$
# Let $\upsilon^2 = \frac{l^2\sigma_p^2}{l^2 + \sigma_p^2}$, $m = \frac{\frac{s}{l^2} + \frac{\mu_p}{\sigma_p^2}}{\frac{1}{l^2} + \frac{1}{\sigma_p^2}}, c_1 = \frac{\frac{s^2}{l^2} + \frac{\mu_p^2}{\sigma_p^2}}{\frac{1}{l^2} + \frac{1}{\sigma_p^2}}$
#
# $$
# \begin{aligned}
#  v[k] &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left(-\frac{1}{2\upsilon^2} \left[\left( t^2 - 2mt
#      \right) + c_1 \right]\right)dt \\
#      &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left(-\frac{1}{2\upsilon^2} \left[ \left(\left(t - m\right)^2 - m^2\right) + c_1\right]\right)dt \\
#      &= \int_a^x \frac{\sigma_f^2}{\sigma_p \sqrt{2 \pi}} \exp \left(-\frac{1}{2\upsilon^2} \left(t - m\right)^2 \right) \exp \left( -\frac{1}{2\upsilon^2} \left[ - m^2 + c_1 \right] \right)  dt \\
# \end{aligned}
# $$
#
#
# Let $c_2(s) := c_2 = \exp \left(\frac{m^2 - c_1}{2\upsilon^2} \right)\,\frac{\upsilon \,\sigma_f^2}{\sigma_p}$
#
#
# $$
# \begin{aligned}
# v[k] &= c_2 \int_a^x \frac{1}{\upsilon \sqrt{2 \pi}} \exp \left(-\frac{1}
#      {2\upsilon^2} \left(t - m\right)^2 \right) dt \\
#      &= c_2 \int_a^x k^*(t,m) dt \\
# \end{aligned}
# $$
#
# If most of the density of $p$ falls in the confident regions of the GP $f$, then we can take $[a,x] = [-\infty, \infty]$.
#
# $\int_{-\infty}^{\infty} k^*(t,m) dt$ integrates to 1 and $v[k] = c_2$.
#
# #### Simplify $\upsilon^2$, $m$, $c_1$ and $c_2$.
#
# Using:
#
# $\upsilon^2 = \frac{l^2 \sigma_p^2}{l^2 + \sigma_p^2}$
#
# $m = \frac{\frac{s}{l^2} + \frac{\mu_p}{\sigma_p^2}}{\frac{1}{l^2} + \frac{1}{\sigma_p^2}} = \frac{s \sigma_p^2 + \mu_p l^2}{l^2 + \sigma_p^2}$
#
# $c_1 = \frac{\frac{s^2}{l^2} + \frac{\mu_p^2}{\sigma_p^2}}{\frac{1}{l^2} + \frac{1}{\sigma_p^2}} = \frac{s^2 \sigma_p^2 + \mu_p^2 l^2}{l^2 + \sigma_p^2}$
#
# $c_2 = \exp \left(\frac{m^2 - c_1}{2\upsilon^2} \right)\,\frac{\upsilon \,\sigma_f^2}{\sigma_p}$
#
# We simplify:
#
# $m^2 - c_1 = \frac{(s \sigma_p^2 + \mu_p l^2)^2}{(l^2 + \sigma_p^2)^2} - \frac{s^2 \sigma_p^2 + \mu_p^2 l^2}{l^2 + \sigma_p^2} = \frac{(s \sigma_p^2 + \mu_p l^2)^2 - (s^2 \sigma_p^2 + \mu_p^2 l^2)(l^2 + \sigma_p^2)}{(l^2 + \sigma_p^2)^2}$
#
# *Numerator 1st term:* $(s \sigma_p^2 + \mu_p l^2)^2 = s^2 \sigma_p^4 + 2 s \mu_p l^2 \sigma_p^2 + \mu_p^2 l^4$
#
# *Numerator 2nd term:* $(s^2 \sigma_p^2 + \mu_p^2 l^2)(l^2 + \sigma_p^2) = s^2 \sigma_p^2 l^2 + s^2 \sigma_p^4 + \mu_p^2 l^4 + \mu_p^2 l^2 \sigma_p^2$
#
# *Numerator:*
# $$
# \begin{aligned}
# (s^2 \sigma_p^4 + 2 s \mu_p l^2 \sigma_p^2 + \mu_p^2 l^4) - (s^2 \sigma_p^4 + s^2 l^2 \sigma_p^2 + \mu_p^2 l^4 + \mu_p^2 l^2 \sigma_p^2) \\
# = 2 s \mu_p l^2 \sigma_p^2 - s^2 l^2 \sigma_p^2 - \mu_p^2 l^2 \sigma_p^2 \\
# = l^2 \sigma_p^2 (2 s \mu_p - s^2 - \mu_p^2) \\
# = - l^2 \sigma_p^2 (s - \mu_p)^2
# \end{aligned}
# $$
#
# $\frac{m^2 - c_1}{2 \upsilon^2} = \frac{- l^2 \sigma_p^2 (s - \mu_p)^2}{2} \cdot \frac{l^2 + \sigma_p^2}{l^2 \sigma_p^2} = - \frac{(l^2 + \sigma_p^2) (s - \mu_p)^2}{2}$
#
#
# $\frac{\upsilon \sigma_f^2}{\sigma_p} = \frac{\sqrt{\frac{l^2 \sigma_p^2}{(l^2 + \sigma_p^2)}} \, \sigma_f^2}{\sigma_p} = \sigma_f^2 {\frac{l}{\sqrt{l^2 + \sigma_p^2}}}$
#
# $$
# \boxed{c_2(s) = \frac{m^2 - c_1}{2 \upsilon^2} \cdot \frac{\upsilon \sigma_f^2}{\sigma_p} = \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \; \exp\left[- \frac{(s - \mu_p)^2}{2 (l^2 + \sigma_p^2)} \right]}
# $$
#
# ---
#
# For the uncertainty we have to integrate again. We will again use $[a,x] = [-\infty, \infty]$.
#
#
# $$
# \begin{aligned}
# vv[k] &= \int \int k(t,s)p(t)p(s) dtds \\
#       &= \int \Big[\int k(t,s)p(t) dt\Big] \,p(s)ds \\
#       &= \int c_2(s) \,p(s)ds \\
#       &= \int \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \; \exp\left[- \frac{(s - \mu_p)^2}{2 (l^2 + \sigma_p^2)} \right] \,\frac{1}{\sigma_p \sqrt{2 \pi}} \exp\left(
#      -\frac{1}{2 \sigma_p^2}(s - \mu_p)^2 \right) ds \\
#      &= \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \,\frac{1}{\sigma_p \sqrt{2 \pi}} \int \exp\left[- \frac{(s - \mu_p)^2}{2 (l^2 + \sigma_p^2)} \right] \exp\left(-\frac{1}{2 \sigma_p^2}(s - \mu_p)^2 \right) ds \\
# \end{aligned}
# $$
#
# Focusing on the integral:
# $$
# \begin{aligned}
# \int \exp\left[- \frac{(s - \mu_p)^2}{2 (l^2 + \sigma_p^2)} \right] \exp\left(-\frac{1}{2 \sigma_p^2}(s - \mu_p)^2 \right) ds
# &= \int \exp\left[- \frac{(s - \mu_p)^2}{2 (l^2 + \sigma_p^2)} - \frac{(s - \mu_p)^2}{2 \sigma_p^2} \right]ds \\
# &= \int \exp \Big[ - (s - \mu_p)^2 \Big( \frac{1}{2 (l^2 + \sigma_p^2)} + \frac{1}{2 \sigma_p^2} \Big) \Big]ds \\
# &= \int \exp \Big[ - (s - \mu_p)^2 \frac{l^2 + 2 \sigma_p^2}{2 \sigma_p^2 (l^2 + \sigma_p^2)} \Big]ds \\
# &= \sqrt{2 \pi} \, \sqrt{\frac{\sigma_p^2 (l^2 + \sigma_p^2)}{l^2 + 2 \sigma_p^2}} \\
# \end{aligned}
# $$
#
# Therefore:
# $$
# \begin{aligned}
# vv[k] &= \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \,\frac{1}{\sigma_p \sqrt{2 \pi}} \int \exp\left[- \frac{(s - \mu_p)^2}{2 (l^2 + \sigma_p^2)} \right] \exp\left(-\frac{1}{2 \sigma_p^2}(s - \mu_p)^2 \right) ds \\
#       &= \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \,\frac{1}{\sigma_p \sqrt{2 \pi}} \left[\sqrt{2 \pi} \, \sqrt{\frac{\sigma_p^2 (l^2 + \sigma_p^2)}{l^2 + 2 \sigma_p^2}} \right]\\
#       &= \sigma_f^2 \sqrt{\frac{l^2}{l^2 + \sigma_p^2}} \,\frac{1}{\sigma_p} \left[\sigma_p\sqrt{\frac{l^2 + \sigma_p^2}{l^2 + 2 \sigma_p^2}} \right]\\
#       &= \sigma_f^2 \sqrt{\frac{l^2}{l^2 + 2 \sigma_p^2}} \\
# \end{aligned}
# $$
#
# ---

# %% [markdown]
# ### 1. **Zero-mean prior**
#
# $$
# \boxed{
# \log p(\mathbf{y} \mid \mathbf{X}, \ell, \sigma_f^2, \sigma_n^2) \propto -\frac{1}{2} \mathbf{y}^\top (K + \sigma_n^2 I)^{-1} \mathbf{y} - \frac{1}{2} \log |K + \sigma_n^2 I|
# }
# $$
#
#
# ### 2. **Negative quadratic mean prior**
#
# $$
# \boxed{
# \log p(\mathbf{y} \mid \mathbf{X}, m_0, \mathbf{x}_m, \mathbf{W}, \ell, \sigma_f^2, \sigma_n^2) \propto -\frac{1}{2} (\mathbf{y} - m(\mathbf{X}))^\top (K + \sigma_n^2 I)^{-1} (\mathbf{y} - m(\mathbf{X})) - \frac{1}{2} \log |K + \sigma_n^2 I|
# }
# $$
#
# with
#
# $$
# m(\mathbf{X}) =
# \begin{bmatrix}
# m_0 - \frac{1}{2} (\mathbf{x}_1 - \mathbf{x}_m)^\top \mathbf{W}^{-1} (\mathbf{x}_1 - \mathbf{x}_m) \\
# \vdots \\
# m_0 - \frac{1}{2} (\mathbf{x}_n - \mathbf{x}_m)^\top \mathbf{W}^{-1} (\mathbf{x}_n - \mathbf{x}_m)
# \end{bmatrix}.
# $$
